# %% [markdown]
# <a href="https://colab.research.google.com/github/nikkijha97/Project/blob/main/loan_defaulters_MFI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("loan_data_set.csv")

# %%
# Dropping Loan_ID
df.drop('Loan_ID', inplace=True, axis=1)

# %%
# Drop Gender rows with nan
df.dropna(axis=0, subset=['Gender','Married','Dependents','Self_Employed','Credit_History'], inplace=True)

# %%
# Drop Gender rows with nan
df.dropna(axis=0, subset=['Gender','Married','Dependents','Self_Employed','Credit_History'], inplace=True)

# %%
# Fill nan values for the LoanAmount as the mean of the column
df['LoanAmount'].fillna(df.LoanAmount.mean(), inplace=True)
# Out:
# <ipython-input-6-7d0fca2318cb>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LoanAmount'].fillna(df.LoanAmount.mean(), inplace=True)

# %%
# We may do the same for the Loan Amount Term
df['Loan_Amount_Term'].fillna(df.Loan_Amount_Term.mean(), inplace=True)
# Out:
# <ipython-input-7-3a4bd528f958>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Loan_Amount_Term'].fillna(df.Loan_Amount_Term.mean(), inplace=True)

# %%
# Lets work with the categorical variables
df[['Gender','Married','Education','Self_Employed','Property_Area','Loan_Status']] = \
df[['Gender','Married','Education','Self_Employed','Property_Area','Loan_Status']].apply(pd.factorize).iloc[0]
# Out:
# <ipython-input-8-43634a7f609e>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df[['Gender','Married','Education','Self_Employed','Property_Area','Loan_Status']] = \

# %%
df
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         0        0          0          0              0             5849
# 1         0        1          1          0              0             4583
# 2         0        1          0          0              1             3000
# 3         0        1          0          1              0             2583
# 4         0        0          0          0              0             6000
# ..      ...      ...        ...        ...            ...              ...
# 609       1        0          0          0              0             2900
# 610       0        1         3+          0              0             4106
# 611       0        1          1          0              0             8072
# 612       0        1          2          0              0             7583
# 613       1        0          0          0              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0  144.136179             360.0             1.0
# 1               1508.0  128.000000             360.0             1.0
# 2                  0.0   66.000000             360.0             1.0
# 3               2358.0  120.000000             360.0             1.0
# 4                  0.0  141.000000             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0   71.000000             360.0             1.0
# 610                0.0   40.000000             180.0             1.0
# 611              240.0  253.000000             360.0             1.0
# 612                0.0  187.000000             360.0             1.0
# 613                0.0  133.000000             360.0             0.0
#
#      Property_Area  Loan_Status
# 0                0            0
# 1                1            1
# 2                0            0
# 3                0            0
# 4                0            0
# ..             ...          ...
# 609              1            0
# 610              1            0
# 611              0            0
# 612              0            0
# 613              2            1
#
# [511 rows x 12 columns]

# %%
Ordinal_dependents = {
    '0': 0,
    '1': 1,
    '2': 2,
    '3+': 3
}
df['Dependents'] = df['Dependents'].map(Ordinal_dependents)

# %%
# Scaling the Numerical variables to be in normal distribution
df.sort_index(ignore_index = True,inplace = True)
df_copy = df.loc[:,'ApplicantIncome':'Loan_Amount_Term'].copy()
df_copy
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# 0               5849                0.0  144.136179             360.0
# 1               4583             1508.0  128.000000             360.0
# 2               3000                0.0   66.000000             360.0
# 3               2583             2358.0  120.000000             360.0
# 4               6000                0.0  141.000000             360.0
# ..               ...                ...         ...               ...
# 506             2900                0.0   71.000000             360.0
# 507             4106                0.0   40.000000             180.0
# 508             8072              240.0  253.000000             360.0
# 509             7583                0.0  187.000000             360.0
# 510             4583                0.0  133.000000             360.0
#
# [511 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_copy = pd.DataFrame(sc.fit_transform(df_copy), columns = df_copy.columns)

# %%
df.loc[:,'ApplicantIncome':'Loan_Amount_Term'] = df_copy.loc[:,'ApplicantIncome':'Loan_Amount_Term'].copy()
# Out:
# <ipython-input-13-446faa5f8701>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[
#   9.12301365e-02 -3.31573899e-01 -5.89864146e-01 -1.12522170e-01
#  -3.43453450e-01 -5.60885241e-01 -5.05447334e-01  6.63910744e-02
#   4.75155640e-01 -1.13062150e-01  2.19445072e+00 -2.75955999e-01
#  -4.16626147e-03 -4.73228550e-01  2.65463558e-01 -1.84879438e-01
#  -3.09614728e-01  2.31414620e+00  1.48467975e-01 -3.04394925e-01
#  -4.30390168e-01  1.99586045e-01 -1.26021660e-01 -5.70604874e-01
#  -5.52425560e-01 -4.57209155e-01 -3.51013165e-01 -5.00767510e-01
#  -5.54643245e-02 -4.54149271e-01  2.38464577e-01 -5.06887279e-01
#  -3.55512995e-01 -5.13727021e-01 -3.08714762e-01  2.87724948e-02
#   8.69520749e-01 -2.55796760e-01 -2.03058752e-01 -2.93955319e-01
#   2.55155724e+00  1.10669402e-01  8.85302384e-02  6.28329856e-01
#  -3.55512995e-01 -3.43453450e-01 -5.27406505e-01 -3.85571860e-01
#  -3.40393566e-01  2.04433639e+00  1.47028030e-01  1.97606120e-01
#  -3.86831813e-01 -3.74232288e-01 -6.34682454e-01  2.21725209e-01
#  -6.24962821e-01 -3.85571860e-01 -4.53789284e-01 -1.84519452e-01
#  -5.41985954e-01 -5.65745057e-01 -4.64768870e-01 -4.15450732e-01
#   1.24528879e-01 -2.60836570e-01  1.94606010e+00 -2.65516393e-01
#   1.93466276e-01  8.37841945e-01  8.49303744e-02  7.10708977e-02
#  -2.93775326e-01  1.20448810e+00 -5.23446654e-01 -3.43453450e-01
#  -2.37797440e-01 -3.73692309e-01 -4.33450052e-01 -2.16378249e-01
#   4.97474797e-01  4.09458121e-01 -1.30521490e-01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:,'ApplicantIncome':'Loan_Amount_Term'] = df_copy.loc[:,'ApplicantIncome':'Loan_Amount_Term'].copy()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size=0.2, random_state=43)

# %%
from sklearn.linear_model import LogisticRegression
LG = LogisticRegression()
LG.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
dev = pd.DataFrame(X_train)
val = pd.DataFrame(X_test)

# %%
dev
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 460       0        1           1          0              0        -0.355513
# 183       0        1           0          0              0        -0.384312
# 170       0        0           2          0              0        -0.069324
# 246       1        0           0          0              0        -0.213138
# 102       1        0           0          0              0        -0.205579
# ..      ...      ...         ...        ...            ...              ...
# 277       1        1           0          0              0        -0.175520
# 305       0        0           0          0              0        -0.505447
# 255       0        1           1          0              0        -0.592924
# 320       0        1           2          0              0        -0.133581
# 324       0        1           0          0              0         0.032372
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 460           0.660181    0.177313          0.280930             1.0
# 183           0.570619   -0.091269          0.280930             1.0
# 170          -0.610901    0.279630          0.280930             0.0
# 246          -0.610901   -0.372640          0.280930             1.0
# 102          -0.610901   -1.280702          0.280930             1.0
# ..                 ...         ...               ...             ...
# 277           0.347691   -0.436588          0.280930             1.0
# 305          -0.610901   -0.615643          2.155051             1.0
# 255           0.533073   -0.398219          0.280930             1.0
# 320          -0.610901   -0.564484          0.280930             1.0
# 324          -0.610901   -0.244744          0.280930             1.0
#
#      Property_Area
# 460              0
# 183              0
# 170              2
# 246              2
# 102              2
# ..             ...
# 277              0
# 305              2
# 255              0
# 320              0
# 324              1
#
# [408 rows x 11 columns]

# %%
val
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 415       0        1           1          0              1        -0.434350
# 141       1        1           0          0              0        -0.130521
# 142       0        1           0          0              0        -0.516427
# 82        0        0           0          0              0        -0.211518
# 140       0        1           0          0              0        -0.288196
# ..      ...      ...         ...        ...            ...              ...
# 335       0        0           0          0              0        -0.505447
# 357       0        1           0          0              0        -0.475568
# 284       0        1           3          1              0        -0.478988
# 236       0        1           0          0              0        -0.396911
# 393       0        1           1          1              0        -0.477908
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 415          -0.610901   -0.628432          0.280930             1.0
# 141          -0.610901   -0.411009          0.280930             1.0
# 142           0.692642   -0.193586          0.280930             1.0
# 82           -0.610901   -0.283113          0.280930             1.0
# 140           0.627328    0.484263          0.000000             1.0
# ..                 ...         ...               ...             ...
# 335           7.211140   -0.526115          0.280930             1.0
# 357           1.070838   -0.295903          0.280930             1.0
# 284           0.009778    0.369157          0.280930             1.0
# 236          -0.102468   -0.820276          0.280930             1.0
# 393          -0.024247   -0.398219         -2.530251             0.0
#
#      Property_Area
# 415              2
# 141              1
# 142              1
# 82               2
# 140              1
# ..             ...
# 335              2
# 357              1
# 284              1
# 236              0
# 393              1
#
# [103 rows x 11 columns]

# %%
train_pred = LG.predict_proba(X_train)[:, 1]
test_pred = LG.predict_proba(X_test)[:, 1]

# %%
dev['actual'] = y_train
dev['pred'] = train_pred
dev.sort_values(by = 'pred')
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 104       0        1           2          0              0        -0.423190
# 394       0        1           3          0              0        -0.111082
# 233       0        1           2          0              0        -0.253457
# 271       0        1           3          0              0        -0.173900
# 381       0        1           2          0              0        -0.260837
# ..      ...      ...         ...        ...            ...              ...
# 216       0        0           0          0              1         1.969459
# 238       0        0           1          1              1        -0.225918
# 58        0        0           0          1              0        -0.379452
# 353       1        0           0          1              0        -0.465849
# 342       0        1           3          0              0        13.624019
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 104          -0.610901   -0.807487          0.280930             1.0
# 394          -0.610901   -0.564484          0.280930             1.0
# 233          -0.610901   -0.692380          0.280930             1.0
# 271          -0.536982   -0.257534          0.280930             1.0
# 381          -0.610901   -0.615643          0.280930             1.0
# ..                 ...         ...               ...             ...
# 216          -0.610901    0.612159          0.280930             0.0
# 238           0.337913    0.177313          0.280930             0.0
# 58            0.270643   -0.231955         -2.530251             0.0
# 353          -0.610901   -0.820276          0.000000             0.0
# 342          -0.610901    2.760812          0.280930             0.0
#
#      Property_Area  actual      pred
# 104              2       0  0.083849
# 394              2       0  0.084035
# 233              2       0  0.086643
# 271              2       0  0.086680
# 381              2       0  0.087120
# ..             ...     ...       ...
# 216              0       1  0.929743
# 238              0       1  0.930867
# 58               0       1  0.932996
# 353              0       1  0.936005
# 342              1       1  0.970960
#
# [408 rows x 13 columns]

# %%
def gini(df):
    deciles = pd.DataFrame((pd.qcut(df['pred'], 10, precision=16)).value_counts()).sort_values(by = 'pred', ascending=False)
    bad_count, good_count = [], []
    for index, row in deciles.iterrows():
        x = df[ (df['pred'] > index.left ) & (df['pred'] <= index.right)]
        bads = len(x[x['actual'] == 1])
        goods = len(x[x['actual'] == 0])
        bad_count.append(bads)
        good_count.append(goods)

    deciles['bads'] = bad_count
    deciles['goods'] = good_count
    deciles['total'] = deciles['goods'] + deciles['bads']
    deciles['cumulative bads'] = deciles['bads'].cumsum()
    deciles['cumulative goods'] = deciles['goods'].cumsum()
    deciles['cumulative total'] = deciles['total'].cumsum()
    deciles['bad rate'] = deciles['bads'] / deciles['total']
    deciles['cum bads%'] = 100* deciles['cumulative bads'] / deciles['bads'].sum()
    deciles['cum goods%'] = 100* deciles['cumulative goods'] / deciles['goods'].sum()
    deciles['cum all%'] = 100* deciles['cumulative total'] / deciles['total'].sum()
    deciles['AUC'] = (
        (deciles['cum bads%'] - deciles['cum bads%'].shift(1, fill_value=0)) *
        (deciles['cum goods%'] + deciles['cum goods%'].shift(1, fill_value=0)) / 2
    ) / 10000
    deciles['area_random'] = (
        (deciles['cum all%'] - deciles['cum all%'].shift(1, fill_value=0)) *
        (deciles['cum all%'] + deciles['cum all%'].shift(1, fill_value=0)) / 2
    ) / 10000
    deciles['B'] = deciles['area_random'] - deciles['AUC']
    deciles['gini'] = 2*deciles['B']

    return deciles, deciles['gini'].sum()

# %%
deciles_dev, gini_dev = gini(dev)

# %%
deciles_dev
# Out:
#                                           count  bads  goods  total  \
# pred
# (0.8287768614852076, 0.9709601916520816]     41    37      3     40
# (0.3083408042625946, 0.8287768614852076]     41    24     17     41
# (0.2607325506074162, 0.3083408042625946]     41     9     32     41
# (0.2305433481282962, 0.2607325506074162]     40    10     30     40
# (0.2041265157203313, 0.2305433481282962]     41     9     32     41
# (0.1840197593387334, 0.2041265157203313]     41     7     34     41
# (0.1645134581478652, 0.1840197593387334]     40    10     30     40
# (0.1357297326359287, 0.1645134581478652]     41     7     34     41
# (0.1131935410842711, 0.1357297326359287]     41     3     38     41
# (0.0838490780251617, 0.1131935410842711]     41     2     39     41
#
#                                           cumulative bads  cumulative goods  \
# pred
# (0.8287768614852076, 0.9709601916520816]               37                 3
# (0.3083408042625946, 0.8287768614852076]               61                20
# (0.2607325506074162, 0.3083408042625946]               70                52
# (0.2305433481282962, 0.2607325506074162]               80                82
# (0.2041265157203313, 0.2305433481282962]               89               114
# (0.1840197593387334, 0.2041265157203313]               96               148
# (0.1645134581478652, 0.1840197593387334]              106               178
# (0.1357297326359287, 0.1645134581478652]              113               212
# (0.1131935410842711, 0.1357297326359287]              116               250
# (0.0838490780251617, 0.1131935410842711]              118               289
#
#                                           cumulative total  bad rate  \
# pred
# (0.8287768614852076, 0.9709601916520816]                40  0.925000
# (0.3083408042625946, 0.8287768614852076]                81  0.585366
# (0.2607325506074162, 0.3083408042625946]               122  0.219512
# (0.2305433481282962, 0.2607325506074162]               162  0.250000
# (0.2041265157203313, 0.2305433481282962]               203  0.219512
# (0.1840197593387334, 0.2041265157203313]               244  0.170732
# (0.1645134581478652, 0.1840197593387334]               284  0.250000
# (0.1357297326359287, 0.1645134581478652]               325  0.170732
# (0.1131935410842711, 0.1357297326359287]               366  0.073171
# (0.0838490780251617, 0.1131935410842711]               407  0.048780
#
#                                            cum bads%  cum goods%   cum all%  \
# pred
# (0.8287768614852076, 0.9709601916520816]   31.355932    1.038062    9.82801
# (0.3083408042625946, 0.8287768614852076]   51.694915    6.920415   19.90172
# (0.2607325506074162, 0.3083408042625946]   59.322034   17.993080   29.97543
# (0.2305433481282962, 0.2607325506074162]   67.796610   28.373702   39.80344
# (0.2041265157203313, 0.2305433481282962]   75.423729   39.446367   49.87715
# (0.1840197593387334, 0.2041265157203313]   81.355932   51.211073   59.95086
# (0.1645134581478652, 0.1840197593387334]   89.830508   61.591696   69.77887
# (0.1357297326359287, 0.1645134581478652]   95.762712   73.356401   79.85258
# (0.1131935410842711, 0.1357297326359287]   98.305085   86.505190   89.92629
# (0.0838490780251617, 0.1131935410842711]  100.000000  100.000000  100.00000
#
#                                                AUC  area_random         B  \
# pred
# (0.8287768614852076, 0.9709601916520816]  0.001627     0.004829  0.003202
# (0.3083408042625946, 0.8287768614852076]  0.008093     0.014974  0.006881
# (0.2607325506074162, 0.3083408042625946]  0.009501     0.025122  0.015621
# (0.2305433481282962, 0.2607325506074162]  0.019647     0.034289  0.014642
# (0.2041265157203313, 0.2305433481282962]  0.025864     0.045171  0.019307
# (0.1840197593387334, 0.2041265157203313]  0.026890     0.055319  0.028429
# (0.1645134581478652, 0.1840197593387334]  0.047798     0.063749  0.015951
# (0.1357297326359287, 0.1645134581478652]  0.040027     0.075367  0.035340
# (0.1131935410842711, 0.1357297326359287]  0.020321     0.085515  0.065194
# (0.0838490780251617, 0.1131935410842711]  0.015806     0.095663  0.079858
#
#                                               gini
# pred
# (0.8287768614852076, 0.9709601916520816]  0.006404
# (0.3083408042625946, 0.8287768614852076]  0.013762
# (0.2607325506074162, 0.3083408042625946]  0.031243
# (0.2305433481282962, 0.2607325506074162]  0.029285
# (0.2041265157203313, 0.2305433481282962]  0.038614
# (0.1840197593387334, 0.2041265157203313]  0.056858
# (0.1645134581478652, 0.1840197593387334]  0.031903
# (0.1357297326359287, 0.1645134581478652]  0.070680
# (0.1131935410842711, 0.1357297326359287]  0.130388
# (0.0838490780251617, 0.1131935410842711]  0.159715

# %%
gini_dev
# Out:
# 0.5688522667292242

# %%
val['actual'] = y_test
val['pred'] = test_pred

# %%
val1 = val[:52]
val2 = val[52:]

# %%
deciles_val1, gini_val1 = gini(val1)

# %%
deciles_val1
# Out:
#                                            count  bads  goods  total  \
# pred
# (0.8595783165215426, 0.9192175368918412]       6     6      0      6
# (0.6446460032811531, 0.8595783165215426]       5     5      0      5
# (0.3046453005086849, 0.6446460032811531]       5     4      1      5
# (0.239958444819826, 0.3046453005086849]        5     1      4      5
# (0.2296640657144599, 0.239958444819826]        5     2      3      5
# (0.1893578509643428, 0.2296640657144599]       5     2      3      5
# (0.173516482171482, 0.1893578509643428]        5     1      4      5
# (0.1571099762526908, 0.173516482171482]        5     3      2      5
# (0.1374186976139517, 0.1571099762526908]       5     1      4      5
# (0.09296946374943388, 0.1374186976139517]      6     1      5      6
#
#                                            cumulative bads  cumulative goods  \
# pred
# (0.8595783165215426, 0.9192175368918412]                 6                 0
# (0.6446460032811531, 0.8595783165215426]                11                 0
# (0.3046453005086849, 0.6446460032811531]                15                 1
# (0.239958444819826, 0.3046453005086849]                 16                 5
# (0.2296640657144599, 0.239958444819826]                 18                 8
# (0.1893578509643428, 0.2296640657144599]                20                11
# (0.173516482171482, 0.1893578509643428]                 21                15
# (0.1571099762526908, 0.173516482171482]                 24                17
# (0.1374186976139517, 0.1571099762526908]                25                21
# (0.09296946374943388, 0.1374186976139517]               26                26
#
#                                            cumulative total  bad rate  \
# pred
# (0.8595783165215426, 0.9192175368918412]                  6  1.000000
# (0.6446460032811531, 0.8595783165215426]                 11  1.000000
# (0.3046453005086849, 0.6446460032811531]                 16  0.800000
# (0.239958444819826, 0.3046453005086849]                  21  0.200000
# (0.2296640657144599, 0.239958444819826]                  26  0.400000
# (0.1893578509643428, 0.2296640657144599]                 31  0.400000
# (0.173516482171482, 0.1893578509643428]                  36  0.200000
# (0.1571099762526908, 0.173516482171482]                  41  0.600000
# (0.1374186976139517, 0.1571099762526908]                 46  0.200000
# (0.09296946374943388, 0.1374186976139517]                52  0.166667
#
#                                             cum bads%  cum goods%    cum all%  \
# pred
# (0.8595783165215426, 0.9192175368918412]    23.076923    0.000000   11.538462
# (0.6446460032811531, 0.8595783165215426]    42.307692    0.000000   21.153846
# (0.3046453005086849, 0.6446460032811531]    57.692308    3.846154   30.769231
# (0.239958444819826, 0.3046453005086849]     61.538462   19.230769   40.384615
# (0.2296640657144599, 0.239958444819826]     69.230769   30.769231   50.000000
# (0.1893578509643428, 0.2296640657144599]    76.923077   42.307692   59.615385
# (0.173516482171482, 0.1893578509643428]     80.769231   57.692308   69.230769
# (0.1571099762526908, 0.173516482171482]     92.307692   65.384615   78.846154
# (0.1374186976139517, 0.1571099762526908]    96.153846   80.769231   88.461538
# (0.09296946374943388, 0.1374186976139517]  100.000000  100.000000  100.000000
#
#                                                 AUC  area_random         B  \
# pred
# (0.8595783165215426, 0.9192175368918412]   0.000000     0.006657  0.006657
# (0.6446460032811531, 0.8595783165215426]   0.000000     0.015717  0.015717
# (0.3046453005086849, 0.6446460032811531]   0.002959     0.024963  0.022004
# (0.239958444819826, 0.3046453005086849]    0.004438     0.034209  0.029771
# (0.2296640657144599, 0.239958444819826]    0.019231     0.043454  0.024223
# (0.1893578509643428, 0.2296640657144599]   0.028107     0.052700  0.024593
# (0.173516482171482, 0.1893578509643428]    0.019231     0.061945  0.042714
# (0.1571099762526908, 0.173516482171482]    0.071006     0.071191  0.000185
# (0.1374186976139517, 0.1571099762526908]   0.028107     0.080436  0.052330
# (0.09296946374943388, 0.1374186976139517]  0.034763     0.108728  0.073964
#
#                                                gini
# pred
# (0.8595783165215426, 0.9192175368918412]   0.013314
# (0.6446460032811531, 0.8595783165215426]   0.031435
# (0.3046453005086849, 0.6446460032811531]   0.044009
# (0.239958444819826, 0.3046453005086849]    0.059541
# (0.2296640657144599, 0.239958444819826]    0.048447
# (0.1893578509643428, 0.2296640657144599]   0.049186
# (0.173516482171482, 0.1893578509643428]    0.085429
# (0.1571099762526908, 0.173516482171482]    0.000370
# (0.1374186976139517, 0.1571099762526908]   0.104660
# (0.09296946374943388, 0.1374186976139517]  0.147929

# %%
gini_val1
# Out:
# 0.5843195266272189

# %%
deciles_val2, gini_val2 = gini(val2)

# %%
gini_val2
# Out:
# 0.5427631578947368

# %%
import numpy as np
def psi_calc(val):
        max_prob=[]
        total_acc=[]
        total_val=[]
        for index, row in deciles_dev.iterrows():
                max_prob.append(index.right)
                total_acc.append(row['total'])
        psi = pd.DataFrame()
        psi['max_prob'] = max_prob
        psi['total_acc'] = total_acc
        psi['acc%'] = 100*(psi['total_acc'] / psi['total_acc'].sum())


        psi = psi.sort_values(by='max_prob')
        psi['max_prob1'] = psi['max_prob'].shift(1, fill_value=0)
        for index, row in psi.iterrows():
                x = val[ (val['pred'] > row['max_prob1'] ) & (val['pred'] <= row['max_prob'])]
                total = len(x)
                total_val.append(total)
        psi['total_val']=total_val
        psi['val%'] = 100*(psi['total_val'] / psi['total_val'].sum())

        psi['PSI'] = (
        (psi['acc%'] - psi['val%']) *
        np.log(psi['acc%'] / psi['val%'])
        ).replace([np.inf, -np.inf, np.nan], 0)
        total_psi = psi['PSI'].sum()
        print(psi)
        print(f'Total PSI: {total_psi}')
psi_calc(val1)
# Out:
#    max_prob  total_acc      acc%  max_prob1  total_val       val%       PSI
# 9  0.113194       41.0  10.07371   0.000000          2   3.846154  5.996236
# 8  0.135730       41.0  10.07371   0.113194          3   5.769231  2.399275
# 7  0.164513       41.0  10.07371   0.135730          8  15.384615  2.248844
# 6  0.184020       40.0   9.82801   0.164513          6  11.538462  0.274441
# 5  0.204127       41.0  10.07371   0.184020          5   9.615385  0.021342
# 4  0.230543       41.0  10.07371   0.204127          2   3.846154  5.996236
# 3  0.260733       40.0   9.82801   0.230543          8  15.384615  2.490090
# 2  0.308341       41.0  10.07371   0.260733          3   5.769231  2.399275
# 1  0.828777       41.0  10.07371   0.308341          8  15.384615  2.248844
# 0  0.970960       40.0   9.82801   0.828777          7  13.461538  1.143109
# Total PSI: 25.21769274724257

# %%
psi_calc(val2)
